# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.colors
import numpy as np

# %%
df18966 = pd.read_csv('18966.csv')

# %%
df18967 = df18966
df18967['Pos_Y_[cm]'] = df18966['Pos_Y_[cm]'].apply(lambda x: -x)
df18967['Dir_Y'] = df18966['Dir_Y'].apply(lambda x: -x)
df18967['Dir_phi_[rad]'] = df18966['Dir_phi_[rad]'].apply(lambda x: -x)
df18967
# Out:
#        Pos_X_[cm]  Pos_Y_[cm]  Pos_Z_[cm]     Pos_u     Pos_v     Dir_X  \
# 0         2.88400   -0.360639    -23.7755  0.484624  0.287669  0.019005
# 1         2.91312   -0.027811    -12.9458  0.469789  0.945068  0.003143
# 2         2.91330   -0.025736     88.1310  0.331327  0.949166  0.003560
# 3         2.90643   -0.104228     18.6159  0.426554  0.794129  0.072397
# 4         2.91150   -0.046254   -263.8040  0.813431  0.908639  0.002597
# ...           ...         ...         ...       ...       ...       ...
# 99995     2.91018   -0.061385     78.7723  0.344148  0.878753  0.003768
# 99996     2.91376   -0.020489    -51.1964  0.522187  0.959530  0.003007
# 99997     2.91173   -0.043701    -99.3289  0.588122  0.913682  0.002957
# 99998     2.91321   -0.026780    -81.4710  0.563659  0.947104  0.003003
# 99999     2.89679   -0.214451    119.8070  0.287935  0.576419  0.047413
#
#           Dir_Y     Dir_Z  Dir_theta_[rad]  Dir_phi_[rad]  LowFluxRatio  \
# ...

# %%
df18967.to_csv('18967.csv');

# %%
df18966
# Out:
#        Pos_X_[cm]  Pos_Y_[cm]  Pos_Z_[cm]     Pos_u     Pos_v     Dir_X  \
# 0         2.88400   -0.360639    -23.7755  0.484624  0.287669  0.019005
# 1         2.91312   -0.027811    -12.9458  0.469789  0.945068  0.003143
# 2         2.91330   -0.025736     88.1310  0.331327  0.949166  0.003560
# 3         2.90643   -0.104228     18.6159  0.426554  0.794129  0.072397
# 4         2.91150   -0.046254   -263.8040  0.813431  0.908639  0.002597
# ...           ...         ...         ...       ...       ...       ...
# 99995     2.91018   -0.061385     78.7723  0.344148  0.878753  0.003768
# 99996     2.91376   -0.020489    -51.1964  0.522187  0.959530  0.003007
# 99997     2.91173   -0.043701    -99.3289  0.588122  0.913682  0.002957
# 99998     2.91321   -0.026780    -81.4710  0.563659  0.947104  0.003003
# 99999     2.89679   -0.214451    119.8070  0.287935  0.576419  0.047413
#
#           Dir_Y     Dir_Z  Dir_theta_[rad]  Dir_phi_[rad]  LowFluxRatio  \
# ...
