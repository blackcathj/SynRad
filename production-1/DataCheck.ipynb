// %%
gSystem->Load("libg4dst");

// %%
!pwd
// Out:
// /gpfs/mnt/gpfs02/sphenix/user/jinhuang/SynRad/production-1

// %%
auto fAna = TFile::Open("./Sum.18966_SynRadAna.root")
// Out:
// (TFile *) @0x7f00c97f8740

// %%
fAna->ls()
// Out:
// TFile**		./Sum.18966_SynRadAna.root
//  TFile*		./Sum.18966_SynRadAna.root
//   KEY: TH2D	h_SynRadAna_BH_1_nHit;1	Hit sum
//   KEY: TH2D	h_SynRadAna_BH_1_photonEnergy;1	Hit source photon
//   KEY: TH2D	h_SynRadAna_BH_1_sumEdep;1	Hit sum energy distribution
//   KEY: TH2D	h_SynRadAna_BH_FORWARD_NEG_nHit;1	Hit sum
//   KEY: TH2D	h_SynRadAna_BH_FORWARD_NEG_photonEnergy;1	Hit source photon
//   KEY: TH2D	h_SynRadAna_BH_FORWARD_NEG_sumEdep;1	Hit sum energy distribution
//   KEY: TH2D	h_SynRadAna_BH_FORWARD_PLUS_nHit;1	Hit sum
//   KEY: TH2D	h_SynRadAna_BH_FORWARD_PLUS_photonEnergy;1	Hit source photon
//   KEY: TH2D	h_SynRadAna_BH_FORWARD_PLUS_sumEdep;1	Hit sum energy distribution
//   KEY: TH2D	h_SynRadAna_CEMC_nHit;1	Hit sum
//   KEY: TH2D	h_SynRadAna_CEMC_photonEnergy;1	Hit source photon
//   KEY: TH2D	h_SynRadAna_CEMC_sumEdep;1	Hit sum energy distribution
//   KEY: TH2D	h_SynRadAna_EEMC_nHit;1	Hit sum
//   KEY: TH2D	h_SynRadAna_EEMC_photonEnergy;1	Hit source photon
// ...

// %%
{
    TCanvas *c1 = new TCanvas("MVTX", "MVTX", 1000, 860);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();
    
    h_SynRadAna_Normalization->Draw();
        
    c1->Draw();
}

// %%
{
    TCanvas *c1 = new TCanvas("h_SynRadAna_photonEnergy", "h_SynRadAna_photonEnergy", 1000, 860);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();
    
    h_SynRadAna_photonEnergy->ProjectionX("Flux",1,1)->Draw();
    Flux->Rebin(10);
    Flux->Scale(0.002905838/10);
        
    c1->Draw();
}

// %%
{
    TCanvas *c1 = new TCanvas("MVTX", "MVTX", 1000, 860);
    
    c1->Divide(2, 1);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_MVTXHit_nHit->GetXaxis()->SetRangeUser(-.5,20);
    h_SynRadAna_MVTXHit_nHit->ProjectionX("Count",2,2)->Draw();

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_MVTXHit_nHit->ProjectionX("Flux",1,1)->Draw();
    Flux->Scale(0.002905838/10);
    h_SynRadAna_MVTXHit_nHit->GetXaxis()->SetRangeUser(-.5,20);
        
    c1->Draw();
}
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: MVTX

// %%
{
    TCanvas *c1 = new TCanvas("MVTX_PHG4Hit", "MVTX_PHG4Hit", 1000, 860);
    
    c1->Divide(2, 1);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_MVTX_nHit->GetXaxis()->SetRangeUser(-.5,20);
    h_SynRadAna_MVTX_nHit->ProjectionX("Count",2,2)->Draw();

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_MVTX_nHit->ProjectionX("Flux",1,1)->Draw();
    Flux->Scale(0.002905838/10);
    h_SynRadAna_MVTXHit_nHit->GetXaxis()->SetRangeUser(-.5,20);
        
    c1->Draw();
}

// %%
{
    TCanvas *c1 = new TCanvas("SynRadAna_MVTX_photonEnergy", "SynRadAna_MVTX_photonEnergy", 1000, 860);
    
    c1->Divide(2, 1);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    TH1 *h_src_photon = (TH1 *)
    (h_SynRadAna_photonEnergy->ProjectionX("Count",2,2)->DrawClone(""));
    h_src_photon->Rebin(40);
//     h_src_photon->Scale(1/10);
    h_src_photon->GetYaxis()->SetRangeUser(1, 1e5);
    
//     h_SynRadAna_MVTX_photonEnergy->Rebin2D(40,1);
//     h_SynRadAna_MVTX_nHit->GetXaxis()->SetRangeUser(-.5,20);
    TH1 *h_mvtx_photon = (TH1 *)(
    h_SynRadAna_MVTX_photonEnergy->ProjectionX("Count",2,2)->DrawClone("same"));
//     h_mvtx_photon->Scale(1/10);
    h_mvtx_photon->Rebin(40);
    
    
    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();
    
    TH1 *h_mvtx_photon_flux = (TH1 *)(
    h_SynRadAna_MVTX_photonEnergy->ProjectionX("Flux",1,1)->DrawClone());
    h_mvtx_photon_flux->Rebin(40);
    h_mvtx_photon_flux->Scale(0.002905838/10);
//     h_SynRadAna_MVTXHit_nHit->GetXaxis()->SetRangeUser(-.5,20);
        
    c1->Draw();
}
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: SynRadAna_MVTX_photonEnergy

// %%
{
    TCanvas *c1 = new TCanvas("SynRadAna_SVTX_photonEnergy", "SynRadAna_SVTX_photonEnergy", 1000, 860);
    
    c1->Divide(2, 1);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_SVTX_photonEnergy->Rebin2D(40,1);
//     h_SynRadAna_MVTX_nHit->GetXaxis()->SetRangeUser(-.5,20);
    h_SynRadAna_SVTX_photonEnergy->ProjectionX("Count",2,2)->Draw();

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_SVTX_photonEnergy->ProjectionX("Flux",1,1)->Draw();
    Flux->Scale(0.002905838/10);
    h_SynRadAna_MVTXHit_nHit->GetXaxis()->SetRangeUser(-.5,20);
        
    c1->Draw();
}

// %%
{
    TCanvas *c1 = new TCanvas("SynRadAna_FST_0_nHit", "SynRadAna_FST_0_nHit", 1000, 860);
    
    c1->Divide(2, 1);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_FST_0_nHit->GetXaxis()->SetRangeUser(-.5,20);
    h_SynRadAna_FST_0_nHit->ProjectionX("Count",2,2)->Draw();

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_FST_0_nHit->ProjectionX("Flux",1,1)->Draw();
    Flux->Scale(0.002905838/10);
    h_SynRadAna_MVTXHit_nHit->GetXaxis()->SetRangeUser(-.5,20);
        
    c1->Draw();
}

// %%
{
    TCanvas *c1 = new TCanvas("SynRadAna_EGEM_0_nHit", "SynRadAna_EGEM_0_nHit", 1000, 860);
    
    c1->Divide(2, 1);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_EGEM_0_nHit->GetXaxis()->SetRangeUser(-.5,20);
    h_SynRadAna_EGEM_0_nHit->ProjectionX("Count",2,2)->Draw();

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_EGEM_0_nHit->ProjectionX("Flux",1,1)->Draw();
    Flux->Scale(0.002905838/10);
        
    c1->Draw();
}

// %%
{
    TCanvas *c1 = new TCanvas("SynRadAna_SVTX_nHit", "SynRadAna_SVTX_nHit", 1000, 860);
    
    c1->Divide(2, 1);
        int idx = 1;
    TPad *p = nullptr;

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_SVTX_nHit->GetXaxis()->SetRangeUser(-.5,20);
    h_SynRadAna_SVTX_nHit->ProjectionX("Count",2,2)->Draw();

    p = (TPad *) c1->cd(idx++);
    c1->Update();
    p->SetLogy();

    h_SynRadAna_SVTX_nHit->ProjectionX("Flux",1,1)->Draw();
    Flux->Scale(0.002905838/10);
        
    c1->Draw();
}

// %%
1e12*1e-6/200e6
// Out:
// (double) 0.0050000000

// %%
1e12*16/1e9
// Out:
// (double) 16000.000
